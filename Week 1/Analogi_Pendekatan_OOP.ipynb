# %% [markdown]
# <a href="https://colab.research.google.com/github/wahyudiputra-dot/Pemrograman-Berorientasi/blob/main/Analogi_Pendekatan_OOP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pemrograman Prosedural

# %%
judul_buku = ["Python Basics", "Machine Learning 101", "Deep Learning", "Deep Horizon"]
penulis = ["Wahyudi Putra", "Zaidan Maulana", "Ifan Setyawan", "Dafa Tirtamaya"]
harga = [150000, 200000, 300000, 450000]
stok = [10, 5, 2, 7]

# Fungsi untuk menampilkan informasi buku
def tampilkan_info_buku(index):
  print(f"Judul: {judul_buku[index]}")
  print(f"Penulis: {penulis[index]}")
  print(f"Harga: Rp{harga[index]}")
  print(f"Stok: {stok[index]}")

# Menampilkan informasi buku pertama
# Karena disini kita memiliki 4 index jadi kita bisa memilih dari 0-3 (Index itu dimulai dari nomor urut 0 ke atas)
tampilkan_info_buku(3)
# Out:
# Judul: Deep Horizon
# Penulis: Dafa Tirtamaya
# Harga: Rp450000
# Stok: 7

# %% [markdown]
# **Contoh jika menggunakan index yang lain**

# %%
judul_buku = ["Python Basics", "Machine Learning 101", "Deep Learning", "Deep Horizon"]
penulis = ["Wahyudi Putra", "Zaidan Maulana", "Ifan Setyawan", "Dafa Tirtamaya"]
harga = [150000, 200000, 300000, 450000]
stok = [10, 5, 2, 7]

# Fungsi untuk menampilkan informasi buku
def tampilkan_info_buku(index):
    print(f"Judul: {judul_buku[index]}")
    print(f"Penulis: {penulis[index]}")
    print(f"Harga: Rp{harga[index]}")
    print(f"Stok: {stok[index]}")

# Menampilkan informasi buku pertama
tampilkan_info_buku(2)
# Out:
# Judul: Deep Learning
# Penulis: Ifan Setyawan
# Harga: Rp300000
# Stok: 2

# %% [markdown]
# Permasalahannya adalah bagaimana jika toko buku tersebut memiliki berbagai banyak buku, dengan macam-macam penulis?

# %%
# Fungsi untuk memasak mie
def masak_mie():
    print("1. Rebus air")
    print("2. Masukkan mie")
    print("3. Tunggu 3 menit")
    print("4. Tambahkan bumbu")
    print("5. Aduk dan sajikan!\n")

# Panggil fungsi untuk memasak mie
masak_mie()
# Out:
# 1. Rebus air
# 2. Masukkan mie
# 3. Tunggu 3 menit
# 4. Tambahkan bumbu
# 5. Aduk dan sajikan!

# %% [markdown]
# Bagaimana jika saya ingin memasak mie kuah rasa karie ayam? atau rasa pedas?

# %% [markdown]
# # OOP

# %% [markdown]
# Object Oriented Programming atau yang biasa disingkat dengan OOP adalah suatu paradigma pemograman yang berfokus pada objek. Dalam pemograman OOP, kita memandang suatu program berisikan objek-objek yang saling mendukung dan berinteraksi satu sama lain. Tidak semua bahasa pemograman dapat mendukung paradigma pemograman ini dan Python adalah salah satu bahasa pemograman yang mendukung OOP.

# %% [markdown]
# Dengan OOP kita bisa menambahkan fitur/atribut tanpa harus menulis ulang kembali programnya

# %%
# Kelas dasar untuk Mie Instan
class MieInstan:
    def __init__(self, rasa):
        self.rasa = rasa

    def masak(self):
        print(f"\nMemasak mie instan rasa {self.rasa}")
        print("1. Rebus air")
        print("2. Masukkan mie")
        print("3. Tunggu 3 menit")
        self.tambahan()
        print("4. Tambahkan bumbu")
        print("5. Aduk dan sajikan!\n")

    def tambahan(self):
        pass

# Kelas untuk Mie Goreng
class MieGoreng(MieInstan):
    def tambahan(self):
        print(">> Tiriskan mie sebelum mencampur bumbu!")

# Kelas untuk Mie Kuah dengan Telur
class MieKuahTelur(MieInstan):
    def tambahan(self):
        print(">> Masukkan telur saat merebus mie!")

# Membuat objek dari kelas MieGoreng dan MieKuahTelur
mie_goreng = MieGoreng("Mie Goreng Spesial")
mie_kuah_telur = MieKuahTelur("Mie Kuah Ayam + Telur")

# Memasak masing-masing varian mie
mie_goreng.masak()
mie_kuah_telur.masak()
# Out:
# Memasak mie instan rasa Mie Goreng Spesial
# 1. Rebus air
# 2. Masukkan mie
# 3. Tunggu 3 menit
# >> Tiriskan mie sebelum mencampur bumbu!
# 4. Tambahkan bumbu
# 5. Aduk dan sajikan!
#
#
# Memasak mie instan rasa Mie Kuah Ayam + Telur
# 1. Rebus air
# 2. Masukkan mie
# 3. Tunggu 3 menit
# >> Masukkan telur saat merebus mie!
# 4. Tambahkan bumbu
# 5. Aduk dan sajikan!

# %% [markdown]
# Menambahkan atribut baru yaitu "level kepedasan" pada mie

# %%
# Kelas dasar untuk Mie Instan
class MieInstan:
    def __init__(self, rasa, level_pedas="Normal"):
        self.rasa = rasa
        self.level_pedas = level_pedas  # Tambahan level kepedasan

    def masak(self):
        print(f"\nMemasak mie instan rasa {self.rasa} (Level Pedas: {self.level_pedas})")
        print("1. Rebus air")
        print("2. Masukkan mie")
        print("3. Tunggu 3 menit")
        self.tambahan()
        print("4. Tambahkan bumbu")
        print("5. Aduk dan sajikan!\n")

    def tambahan(self):
        pass

# Kelas untuk Mie Goreng
class MieGoreng(MieInstan):
    def tambahan(self):
        print(">> Tiriskan mie sebelum mencampur bumbu!")

# Kelas untuk Mie Kuah dengan Telur
class MieKuahTelur(MieInstan):
    def tambahan(self):
        print(">> Masukkan telur saat merebus mie!")

# Membuat objek dari kelas MieGoreng dan MieKuahTelur
mie_goreng = MieGoreng("Mie Goreng Spesial", "Tidak Pedas")
mie_kuah_telur = MieKuahTelur("Mie Kuah Ayam + Telur", "Sedang")

# Memasak masing-masing varian mie
mie_goreng.masak()
mie_kuah_telur.masak()

# Membuat mie instan biasa dengan level kepedasan tinggi
mie_pedas = MieInstan("Ayam Geprek", "Super Pedas")
mie_pedas.masak()
# Out:
# Memasak mie instan rasa Mie Goreng Spesial (Level Pedas: Tidak Pedas)
# 1. Rebus air
# 2. Masukkan mie
# 3. Tunggu 3 menit
# >> Tiriskan mie sebelum mencampur bumbu!
# 4. Tambahkan bumbu
# 5. Aduk dan sajikan!
#
#
# Memasak mie instan rasa Mie Kuah Ayam + Telur (Level Pedas: Sedang)
# 1. Rebus air
# 2. Masukkan mie
# 3. Tunggu 3 menit
# >> Masukkan telur saat merebus mie!
# 4. Tambahkan bumbu
# 5. Aduk dan sajikan!
#
#
# Memasak mie instan rasa Ayam Geprek (Level Pedas: Super Pedas)
# 1. Rebus air
# 2. Masukkan mie
# 3. Tunggu 3 menit
# 4. Tambahkan bumbu
# 5. Aduk dan sajikan!
